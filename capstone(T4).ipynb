# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('hr_Hiring_details.csv')
df2 = pd.read_csv('LOB_mapping_P4.csv')

# %%
res1 = pd.merge(df1,df2,on="LOB_id",how="inner")

# %%
res1
# Out:
#         Sno  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice period Offered band  Pecent hike expected in CTC  \
# 0                30           E2                       -20.79
# ...

# %%
df3 = pd.read_csv("Employee_joining_status.csv")

# %%
res2 = pd.merge(res1,df3,on="Candidate Ref")

# %%
res2
# Out:
#         Sno  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice period Offered band  Pecent hike expected in CTC  \
# 0                30           E2                       -20.79
# ...

# %%
res2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8995 entries, 0 to 8994
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sno                          8995 non-null   int64
#  1   Candidate Ref                8995 non-null   int64
#  2   DOJ Extended                 8995 non-null   object
#  3   Duration to accept offer     8995 non-null   int64
#  4   Notice period                8995 non-null   int64
#  5   Offered band                 8982 non-null   object
#  6   Pecent hike expected in CTC  8995 non-null   float64
#  7   Percent hike offered in CTC  8995 non-null   float64
#  8   Percent difference CTC       8995 non-null   float64
#  9   Joining Bonus                8995 non-null   object
#  10  Candidate relocate actual    8995 non-null   object
#  11  Gender                       8995 non-null   object
#  12  Candidate Source             8995 non-null   object
# ...

# %%
res2.describe()
# Out:
#                 Sno  Candidate Ref  Duration to accept offer  Notice period  \
# count   8995.000000   8.995000e+03               8995.000000    8995.000000
# mean    5970.984325   2.843647e+06                 21.434464      39.291829
# std     3373.963454   4.863448e+05                 25.811616      22.220239
# min        1.000000   2.109586e+06                  0.000000       0.000000
# 25%     3207.500000   2.386476e+06                  3.000000      30.000000
# 50%     5976.000000   2.807482e+06                 10.000000      30.000000
# 75%     8739.000000   3.300060e+06                 33.000000      60.000000
# max    12333.000000   3.836076e+06                224.000000     120.000000
#
#        Pecent hike expected in CTC  Percent hike offered in CTC  \
# count                  8995.000000                  8995.000000
# mean                     43.864804                    40.657356
# std                      29.788975                    36.064060
# ...

# %%
res2.isna().sum()
# Out:
# Sno                               0
# Candidate Ref                     0
# DOJ Extended                      0
# Duration to accept offer          0
# Notice period                     0
# Offered band                     13
# Pecent hike expected in CTC       0
# Percent hike offered in CTC       0
# Percent difference CTC            0
# Joining Bonus                     0
# Candidate relocate actual         0
# Gender                            0
# Candidate Source                  0
# Rex in Yrs                        0
# Location                          0
# Age                              15
# LOB_id                            0
# Unnamed: 17                    8994
# LOB                               0
# Status                            0
# dtype: int64

# %%
res2.drop("Unnamed: 17",axis=1,inplace=True)

# %%
res2
# Out:
#         Sno  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice period Offered band  Pecent hike expected in CTC  \
# 0                30           E2                       -20.79
# ...

# %%
res2.isna().sum()
# Out:
# Sno                             0
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                   13
# Pecent hike expected in CTC     0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                            15
# LOB_id                          0
# LOB                             0
# Status                          0
# dtype: int64

# %%
res2.head()
# Out:
#    Sno  Candidate Ref DOJ Extended  Duration to accept offer  Notice period  \
# 0    1        2110407          Yes                        14             30
# 1    2        2112635           No                        18             30
# 2    3        2112838           No                         3             45
# 3    4        2115021           No                        26             30
# 4    5        2115125          Yes                         1            120
#
#   Offered band  Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0           E2                       -20.79                        13.16
# 1           E2                        50.00                       320.00
# 2           E2                        42.84                        42.84
# 3           E2                        42.84                        42.84
# 4           E2                        42.59                        42.59
#
# ...

# %%
a=res2['Candidate Ref'].nunique()

# %%
a
# Out:
# 8995

# %%
res2['DOJ Extended'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
res2['Offered band'].unique()
# Out:
# array(['E2', 'E1', 'E3', nan, 'E0'], dtype=object)

# %%
ce1 =res2[res2['Offered band']=='E1']

# %%
ce1['Offered band'].count()
# Out:
# 5565

# %%
sum1=ce1['Age'].tolist()

# %%
res2['Age'].unique()
# Out:
# array([34., 27., 32., 26., 29., 36., 30., 31., 40., 28., 33., 25., 44.,
#        23., 41., 20., 37., 24., 35., 50., 42., 38., 39., 21., nan, 45.,
#        46., 43., 22., 49., 47., 48., 60., 51.])

# %%
#res2.dropna(inplace=True)

# %%
res2.isna().sum()
# Out:
# Sno                             0
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                   13
# Pecent hike expected in CTC     0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                            15
# LOB_id                          0
# LOB                             0
# Status                          0
# dtype: int64

# %%
res2.groupby('Rex in Yrs').Age.median()
# Out:
# Rex in Yrs
# 0     23.0
# 1     25.0
# 2     26.0
# 3     28.0
# 4     29.0
# 5     30.0
# 6     31.0
# 7     33.0
# 8     34.0
# 9     34.0
# 10    34.0
# 11    35.0
# 12    36.0
# 13    38.0
# 14    37.0
# 15    41.0
# 16    39.0
# 17    34.0
# 18    34.0
# 20    44.0
# 22    39.5
# 24    38.0
# Name: Age, dtype: float64

# %%
def fill_missing_age(a):
    median_age = a.groupby('Rex in Yrs')['Age'].transform("median")
    a['Age'] = a['Age'].fillna(median_age)
    return a

df_res = fill_missing_age(res2)
print(df_res)
# Out:
#         Sno  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice period Offered band  Pecent hike expected in CTC  \
# 0                30           E2                       -20.79
# ...

# %% [raw]
# res2

# %%
res2.isna().sum()
# Out:
# Sno                             0
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                   13
# Pecent hike expected in CTC     0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                             0
# LOB_id                          0
# LOB                             0
# Status                          0
# dtype: int64

# %%
res2['Age'].isna().sum()
# Out:
# 0

# %%
res2.groupby(['Rex in Yrs'])['Offered band'].agg(pd.Series.mode)
# Out:
# Rex in Yrs
# 0           E0
# 1           E1
# 2           E1
# 3           E1
# 4           E1
# 5           E1
# 6           E2
# 7           E2
# 8           E2
# 9           E2
# 10          E2
# 11          E3
# 12          E2
# 13          E3
# 14          E3
# 15          E3
# 16          E3
# 17          E2
# 18          E3
# 20          E3
# 22    [E2, E3]
# 24          E3
# Name: Offered band, dtype: object

# %%
def fill_missing_Offeredband(a):
    mode_ob = a.groupby('Rex in Yrs')['Offered band'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None)
    a['Offered band'] = a['Offered band'].fillna(a['Rex in Yrs'].map(mode_ob))
    return a

df_res2 = fill_missing_Offeredband(res2)

# %%
res2.isna().sum()
# Out:
# Sno                            0
# Candidate Ref                  0
# DOJ Extended                   0
# Duration to accept offer       0
# Notice period                  0
# Offered band                   0
# Pecent hike expected in CTC    0
# Percent hike offered in CTC    0
# Percent difference CTC         0
# Joining Bonus                  0
# Candidate relocate actual      0
# Gender                         0
# Candidate Source               0
# Rex in Yrs                     0
# Location                       0
# Age                            0
# LOB_id                         0
# LOB                            0
# Status                         0
# dtype: int64

# %% [raw]
# #Renaming the Columns of expected offer

# %%
res2 = res2.rename(columns={"Pecent hike expected in CTC":"Percent hike expected in CTC"})

# %%
res2
# Out:
#         Sno  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice period Offered band  Percent hike expected in CTC  \
# 0                30           E2                        -20.79
# ...

# %%
contains_negative_expected = (res2['Percent hike expected in CTC']<0).any()

# %%
contains_negative_expected
# Out:
# True

# %%
contains_negative_offered = (res2['Percent hike offered in CTC']<0).any()

# %%
contains_negative_offered
# Out:
# True

# %%
res2['Percent hike expected in CTC'] = res2['Percent hike expected in CTC'].abs()

# %%
res2['Percent hike offered in CTC'] = res2['Percent hike offered in CTC'].abs()

# %%
contains_negative_expected
# Out:
# True

# %%
contains_negative_offered
# Out:
# True

# %%
res2
# Out:
#         Sno  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice period Offered band  Percent hike expected in CTC  \
# 0                30           E2                         20.79
# ...

# %%
res2['Percent difference CTC'] = res2['Percent hike offered in CTC'] - res2['Percent hike expected in CTC'].abs()

# %%
res2.head(10)
# Out:
#    Sno  Candidate Ref DOJ Extended  Duration to accept offer  Notice period  \
# 0    1        2110407          Yes                        14             30
# 1    2        2112635           No                        18             30
# 2    3        2112838           No                         3             45
# 3    4        2115021           No                        26             30
# 4    5        2115125          Yes                         1            120
# 5    6        2117167          Yes                        17             30
# 6    7        2119124          Yes                        37             30
# 7    9        2127572          Yes                        16              0
# 8   11        2138169           No                         1             30
# 9   12        2143362           No                         6             30
#
#   Offered band  Percent hike expected in CTC  Percent hike offered in CTC  \
# ...

# %%
import matplotlib.pyplot as plt
status_count = res2['Status'].value_counts()

plt.bar(status_count.index,status_count.values,color=['green','red'])
plt.title("Status of Joined or Not")
plt.xlabel("Status")
plt.ylabel("Count")
plt.show()

# %%
res2.corr
# Out:
# <bound method DataFrame.corr of         Sno  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice period Offered band  Percent hike expected in CTC  \
# 0                30           E2                         20.79
# ...

# %%
res2['DOJ Extended'] = res2['DOJ Extended'].map({'Yes': 1, 'No': 0})
res2['Joining Bonus'] = res2['Joining Bonus'].map({'Yes': 1, 'No': 0})
res2['Candidate relocate actual'] = res2['Candidate relocate actual'].map({'Yes': 1, 'No': 0})
res2['Gender'] = res2['Gender'].map({'Female': 0, 'Male': 1})  # Example: Female=0, Male=1
res2['Offered band'] = res2['Offered band'].map({'E0':0,'E1':1,'E2':2,'E3':3})
res2['Candidate Source'] = res2['Candidate Source'].map({'Agency':0,'Employee Referral':1,'Direct':2})
res2['Status'] = res2['Status'].map({'Joined': 1, 'Not Joined': 0})  # Target variable
res2['Location'] = res2['Location'].map({'Ahmedabad':0,'Bangalore':1,'Chennai':2,'Cochin':3,'Gurgaon':4,'Hyderabad':5,'Kolkata':6,'Mumbai':7,'Noida':8,'Pune':9,'Others':10})

# %%
res2.isna().sum()
# Out:
# Sno                             0
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                    0
# Percent hike expected in CTC    0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                             0
# LOB_id                          0
# LOB                             0
# Status                          0
# dtype: int64

# %%
res2.head()
# Out:
#    Sno  Candidate Ref  DOJ Extended  Duration to accept offer  Notice period  \
# 0    1        2110407             1                        14             30
# 1    2        2112635             0                        18             30
# 2    3        2112838             0                         3             45
# 3    4        2115021             0                        26             30
# 4    5        2115125             1                         1            120
#
#    Offered band  Percent hike expected in CTC  Percent hike offered in CTC  \
# 0             2                         20.79                        13.16
# 1             2                         50.00                       320.00
# 2             2                         42.84                        42.84
# 3             2                         42.84                        42.84
# 4             2                         42.59                        42.59
#
# ...

# %%
res2.isna().sum()
# Out:
# Sno                             0
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                    0
# Percent hike expected in CTC    0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                             0
# LOB_id                          0
# LOB                             0
# Status                          0
# dtype: int64

# %%
df = res2

# %%
df.drop(columns='LOB',inplace=True)

# %%
import seaborn as sns
plt.figure(figsize = (30,10))
sns.heatmap(res2.corr(),annot=True)
# Out:
# <Axes: >

# %%
y = df['Status']

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8990    1
# 8991    1
# 8992    1
# 8993    1
# 8994    1
# Name: Status, Length: 8995, dtype: int64

# %%
x = df
# x = df.drop(columns="Status",inplace=True)

# %%
x['Age'] = x['Age'].astype('int')

# %%
x.drop(columns = ['Candidate Ref', 'Percent hike offered in CTC', 'Percent hike expected in CTC'], inplace=True)

# %%
x
# Out:
#         Sno  DOJ Extended  Duration to accept offer  Notice period  \
# 0         1             1                        14             30
# 1         2             0                        18             30
# 2         3             0                         3             45
# 3         4             0                        26             30
# 4         5             1                         1            120
# ...     ...           ...                       ...            ...
# 8990  12319             0                         4              0
# 8991  12327             1                         2              0
# 8992  12331             0                         0              0
# 8993  12332             0                         0             30
# 8994  12333             0                         2              0
#
#       Offered band  Percent difference CTC  Joining Bonus  \
# 0                2                   -7.63              0
# ...

# %%
x.drop(columns='Sno',inplace=True)

# %%
x['Percent difference CTC'] = x['Percent difference CTC'].astype('int').abs()

# %%
x
# Out:
#       DOJ Extended  Duration to accept offer  Notice period  Offered band  \
# 0                1                        14             30             2
# 1                0                        18             30             2
# 2                0                         3             45             2
# 3                0                        26             30             2
# 4                1                         1            120             2
# ...            ...                       ...            ...           ...
# 8990             0                         4              0             1
# 8991             1                         2              0             1
# 8992             0                         0              0             2
# 8993             0                         0             30             1
# 8994             0                         2              0             1
#
#       Percent difference CTC  Joining Bonus  Candidate relocate actual  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,precision_score,accuracy_score

# %%
rf = RandomForestClassifier(n_estimators=50,random_state=2)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.2 ,random_state = 2)

# %%
rf_model = rf.fit(xtrain,ytrain)

# %%
y_test_pred = rf_model.predict(xtest)

# %%
y_train_pred = rf_model.predict(xtrain)

# %%
print(f'Train Score : {accuracy_score(ytrain,y_train_pred)}')
# Out:
# Train Score : 0.9886047804335742

# %%
print(f'Fitted Score : {accuracy_score(ytest,y_test_pred)}')
# Out:
# Fitted Score : 0.8154530294608116

# %%
print(f'Fitted Score : {precision_score(ytest,y_test_pred)}')
# Out:
# Fitted Score : 0.8445121951219512

# %%
rf_model.feature_importances_
# Out:
# array([0.2952022 , 0.08126452, 0.18932232, 0.04160291, 0.03083114,
#        0.04401123, 0.14762889, 0.07717331, 0.09296349])

# %%
xtrain.columns
# Out:
# Index(['Duration to accept offer', 'Notice period', 'Percent difference CTC',
#        'Candidate relocate actual', 'Gender', 'Candidate Source', 'Rex in Yrs',
#        'Location', 'LOB_id'],
#       dtype='object')

# %%
x.drop(columns=['DOJ Extended','Offered band','Joining Bonus','Age'],inplace=True)

# %%
x.drop(columns='Gender',inplace=True)
